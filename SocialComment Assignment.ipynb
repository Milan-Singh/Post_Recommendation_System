# %% [markdown]
# # TheSocialComment Machine Learning Assignment
# ## Coded By: Milan Singh
#
# ## Tasks
# You have to build a Recommendation System, recommending the items based on the following.
# 1. Content Based Filtering
# 2. Collaborative Filtering<br>
# <br>End result should be a system that.
# * Recommend posts for the given user
# * Recommend similar posts for the given post

# %% [markdown]
# ### Dataset Details
#
#
# | Dataset | Description   |
# |------|------|
# | users.csv | Users dataset containing user's details like name, id, gender etc. |
# | posts.csv |Post dataset containing posts details like title category etc.|
# | views.csv | Views dataset contains the mapping which user views which post(s) |

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
users = pd.read_csv("C:/Users/Trentino Sinz/Desktop/SocialComment Private Limited/Mldata/users.csv")
posts = pd.read_csv("C:/Users/Trentino Sinz/Desktop/SocialComment Private Limited/Mldata/posts.csv")
views = pd.read_csv("C:/Users/Trentino Sinz/Desktop/SocialComment Private Limited/Mldata/views.csv")

# %%
users.head()
# Out:
#                         _id                  name gender      academics
# 0  5d60098a653a331687083238  Nivesh Singh Chauhan   male  undergraduate
# 1  5d610ae1653a331687083239         Gaurav Sharma   male       graduate
# 2  5d618359fc5fcf3bdd9a0910         Akshay Mishra   male  undergraduate
# 3  5d6d2bb87fa40e1417a49315        Saksham Mathur   male  undergraduate
# 4  5d7c994d5720533e15c3b1e9         Varun Chowhan   male  undergraduate

# %% [markdown]
# #### Users
# * _id: a unique alphanumeric id of the user (string)
# * name: Name of user (string)
# * gender: Gender of user (male | female)
# * academics: Education of the use (undergraduate | graduate)

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 4 columns):
# _id          118 non-null object
# name         118 non-null object
# gender       118 non-null object
# academics    118 non-null object
# dtypes: object(4)
# memory usage: 3.8+ KB

# %%
users.shape
# Out:
# (118, 4)

# %%
users.isnull().sum(axis=0)
# Out:
# _id          0
# name         0
# gender       0
# academics    0
# dtype: int64

# %%
posts.head()
# Out:
#                         _id                          title  \
# 0  5d62abaa65218653a132c956                    hello there
# 1  5d6d39567fa40e1417a4931c                      Ml and AI
# 2  5d7d23315720533e15c3b1ee  What is an Operating System ?
# 3  5d7d405e5720533e15c3b1f3                     Lord Shiva
# 4  5d80dfbc6c53455f896e600e   How Competition law evolved?
#
#                                             category  post_type
# 0                                Plant Biotechnology       blog
# 1  Artificial Intelligence|Machine Learning|Infor...       blog
# 2                                  Operating Systems       blog
# 3                                           Drawings    artwork
# 4                                   Competition Laws       blog

# %% [markdown]
# #### Posts
# * _id: a unique alphanumeric id of the post (string)
# * title: Title of the post (string)
# * category: Category of the post (string)
# * post_type: Type of the post (blog | artwork | skill | project)

# %%
posts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 493 entries, 0 to 492
# Data columns (total 4 columns):
# _id           493 non-null object
# title         493 non-null object
# category      465 non-null object
#  post_type    493 non-null object
# dtypes: object(4)
# memory usage: 15.5+ KB

# %%
posts.shape
# Out:
# (493, 4)

# %%
posts.isnull().sum(axis=0)
# Out:
# _id            0
# title          0
# category      28
#  post_type     0
# dtype: int64

# %%
views.head()
# Out:
#                     user_id                   post_id  \
# 0  5df49b32cc709107827fb3c7  5ec821ddec493f4a2655889e
# 1  5ed3748576027d35905ccaab  5ed4cbadbd514d602c1531a6
# 2  5ed0defa76027d35905cc2de  5eac305f10426255a7aa9dd3
# 3  5ed0defa76027d35905cc2de  5ed1ff0276027d35905cc60d
# 4  5ed0defa76027d35905cc2de  5ed3820f76027d35905ccac8
#
#                   timestamp
# 0  2020-06-01T10:46:45.131Z
# 1  2020-06-01T09:39:20.021Z
# 2  2020-06-01T08:12:42.682Z
# 3  2020-06-01T08:10:23.880Z
# 4  2020-06-01T08:08:54.124Z

# %% [markdown]
# #### Views
# * user_id : a unique alphanumeric id of the user (string)
# * post_id : a unique alphanumeric id of the post (string)
# * time stamp: timestamp of when user viewed the post (ISO time format)

# %%
views.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1449 entries, 0 to 1448
# Data columns (total 3 columns):
# user_id      1449 non-null object
# post_id      1449 non-null object
# timestamp    1449 non-null object
# dtypes: object(3)
# memory usage: 34.0+ KB
# user_id      0
# post_id      0
# timestamp    0
# dtype: int64

# %%
views.shape
# Out:
# (1449, 3)

# %%
views.isnull().sum(axis=0)
# Out:
# user_id      0
# post_id      0
# timestamp    0
# dtype: int64

# %% [markdown]
# ### Working on users file

# %%
sns.countplot(x='gender',data=users)

# %% [markdown]
# We see that we have some people with undefined gender

# %%
users['gender'].value_counts()
# Out:
# male         72
# female       44
# undefined     2
# Name: gender, dtype: int64

# %%
users[users['gender']=='undefined']
# Out:
#                          _id          name     gender  academics
# 67  5ea43f7310426255a7aa9b1d  Apoorva Rana  undefined  undefined
# 74  5ea890e410426255a7aa9c16      Gretchen  undefined  undefined

# %% [markdown]
# According to the search engine of GOOGLE, these names are for girls (female)

# %%
users['gender'].iloc[67] = 'female'

# %%
users['gender'].iloc[74] = 'female'

# %%
sns.countplot(x='gender',data=users,palette='husl')

# %%
sns.countplot(x='academics',data=users)

# %%
users[users['academics']=='undefined']
# Out:
#                          _id          name  gender  academics
# 67  5ea43f7310426255a7aa9b1d  Apoorva Rana  female  undefined
# 74  5ea890e410426255a7aa9c16      Gretchen  female  undefined

# %%
users['academics'].iloc[67] = 'undergraduate'

# %%
users['academics'].iloc[67] = 'undergraduate'

# %% [markdown]
# ### Working on posts file

# %% [markdown]
# Checking for missing values

# %%
posts.isnull().sum()
# Out:
# _id            0
# title          0
# category      28
#  post_type     0
# dtype: int64

# %%
x = posts[posts['category'].isna()==True]
x
# Out:
#                           _id  \
# 24   5ddeb6e80eb5e25a8a07f065
# 25   5de179d80eb5e25a8a07f079
# 29   5dee9b5042a8854bf6eabaaf
# 65   5e3ea110eab55d319938a7a7
# 88   5e4c3873f5561b1994c8e3d9
# 93   5e4da502f5561b1994c8e42c
# 94   5e4da7c8f5561b1994c8e439
# 95   5e4dab15f5561b1994c8e446
# 96   5e4ed85af5561b1994c8e470
# 97   5e4ed8ccf5561b1994c8e47d
# 98   5e4edd1bf5561b1994c8e48a
# 99   5e4edd87f5561b1994c8e497
# 227  5e8c2d01a3258347b42f2627
# 228  5e8c993da3258347b42f264d
# 229  5e8cb88ea3258347b42f267e
# 230  5e8cc876a3258347b42f26a3
# 231  5e8ccfb5a3258347b42f26bc
# 352  5ea5aacd10426255a7aa9b71
# 353  5ea5ce9310426255a7aa9b8d
# 374  5eaf3d4110426255a7aa9f4c
# 394  5eb1df6d10426255a7aaa029
# 442  5eca8fceeaff6b0c3a58a3c0
# 463  5ed0e31a76027d35905cc302
# 464  5ed0e65976027d35905cc356
# 465  5ed0f0c576027d35905cc3c7
# 468  5ed175f176027d35905cc554
# 469  5ed175f476027d35905cc562
# 490  5ed3ef4cbd514d602c1530f2
#
#                                                  title category  post_type
# 24   Library Managment System: Software Requirement...      NaN    project
# 25          Navigation system using BFS DFS algorithms      NaN    project
# 29               Computer Aided Machine Drawing (CAMD)      NaN    project
# 65                                                  OS      NaN    project
# 88                               Bill Calculation(PHP)      NaN    project
# 93                                      Prime No.(PHP)      NaN    project
# 94                             Factorial of a No.(PHP)      NaN    project
# 95                                 Palindrome No.(PHP)      NaN    project
# 96                                    Factorial (.net)      NaN    project
# 97                           Leap year checking (.net)      NaN    project
# 98                                     Delegates(.net)      NaN    project
# 99                            Overloading Method(.net)      NaN    project
# 227                         Even and Odd Numbers (PHP)      NaN    project
# 228                             Armstrong No.(C# .Net)      NaN    project
# 229                               Palindrome (C# .Net)      NaN    project
# 230                     Negative or Positive No. (PHP)      NaN    project
# 231                            Friend Number (C# .Net)      NaN    project
# 352                            Photography Composition      NaN    project
# 353                                        Photography      NaN    project
# 374                               Students Networking!      NaN       blog
# 394                          Novel & Consenent (P.H.P)      NaN    project
# 442                               Zero-Waste Lifestyle      NaN    project
# 463  Designing Cmos circuit from Boolean expression...      NaN    project
# 464                        Moore FSM Sequence Detector      NaN    project
# 465              Designing Circular Microstrip Antenna      NaN    project
# 468                                 GAN's Introduction      NaN    project
# 469                                 GAN's Introduction      NaN    project
# 490                              Recommendation Engine      NaN    project

# %%
posts['category'].value_counts()
# Out:
# Photography                                                                                                             81
# Drawings                                                                                                                47
# Painting                                                                                                                20
# Visual Arts                                                                                                             10
# Computer Technology|Machine Learning                                                                                     7
# Computer Technology|Computer Application|Information Technology                                                          7
# Competition Laws                                                                                                         5
# Typography|Pen and ink                                                                                                   5
# Mass Media|Indian Government                                                                                             5
# Computer Technology|Information Technology                                                                               4
# Photography|Architecture                                                                                                 4
# Computer Technology|Computer Application                                                                                 4
# Computer Technology|Cloud Computing                                                                                      3
# Marketing|Advertising                                                                                                    3
# Mixed Media                                                                                                              3
# Calligraphy|Typography|Pen and ink                                                                                       3
# Art                                                                                                                      3
# Business|Business Organisation                                                                                           3
# Pen and ink                                                                                                              3
# Geography|Physical Geography                                                                                             3
# Drawing                                                                                                                  3
# Typography|Calligraphy|Pen and ink                                                                                       2
# Drawings|Fashion Design|Illustration|Watercolours                                                                        2
# Graphics|Computer Creation                                                                                               2
# Literature|Stories                                                                                                       2
# Watercolours                                                                                                             2
# Drawings|Painting                                                                                                        2
# Accounting|Fundamental Of Accounting                                                                                     2
# Computer Technology|Programming languages                                                                                2
# Philosophy|Logic                                                                                                         2
#                                                                                                                         ..
# Photography|Architecture|Visual Arts|Graphic Design                                                                      1
# Literature|Movements in Literature                                                                                       1
# Photography|Conceptual|Illustration                                                                                      1
# E Commerce|Shopping Platform|Other Online Platforms                                                                      1
# Operating Systems                                                                                                        1
# Computer Technology|Hardware|Information Technology                                                                      1
# Auditing|Internal Audit                                                                                                  1
# Science; Technology                                                                                                      1
# Social Work|Health Education                                                                                             1
# Social Work|Social Tech                                                                                                  1
# Management|Business Management|Technology Mangement|Managerial Activity|Creative And Lateral Management                  1
# Mass Media|Media And Society                                                                                             1
# Economics|Economics Sociology                                                                                            1
# Computer Technology|Computer Application|Hardware|Information Technology                                                 1
# Business|Business Strategies|Venture Capitalist                                                                          1
# Drawings|Painting|Visual Arts|Graphic Design|Prints|Illustration                                                         1
# Drawings|Artistic design                                                                                                 1
# Psycholgy|Child Development                                                                                              1
# Drawings|Fashion Design|Mixed Media|Conceptual|Illustration|Pen and ink|Watercolours                                     1
# Business|Bio-entrepreneurship                                                                                            1
# Photography|Architecture|Visual Arts|Graphic Design|Artistic design|Graphic|Logo Design                                  1
# Drawings|Artistic design|Illustration                                                                                    1
# Economic Policies                                                                                                        1
# Computer Technology|Web designing|Artificial Intelligence|Computer Application|Machine Learning|Frontend Development     1
# Visual Arts|Craft|Mixed Media|Conceptual|Mosaic painting                                                                 1
# Fine Arts|Painting                                                                                                       1
# Inorganic Chemistry                                                                                                      1
# Taxation|Custom Laws                                                                                                     1
# Music                                                                                                                    1
# Empowerment                                                                                                              1
# Name: category, Length: 231, dtype: int64

# %%
post_WNA = posts.dropna()
post_WNA.index = np.arange(0,post_WNA.shape[0])

categories=[]
for i in range(0,post_WNA.shape[0]):
    temp=post_WNA['category'][i].split('|')
    for j in range(0,len(temp)):
        categories.append(temp[j])
    temp=[]
    
categories = list(dict.fromkeys(categories))

# %%
categories
# Out:
# ['Plant Biotechnology',
#  'Artificial Intelligence',
#  'Machine Learning',
#  'Information Technology',
#  'Operating Systems',
#  'Drawings',
#  'Competition Laws',
#  'Eco System',
#  'Economic Policies',
#  'Graphic',
#  'Graphic Design',
#  'Painting',
#  'Pen and ink',
#  'Computer Technology',
#  'Visual Arts',
#  'Illustration',
#  'Calligraphy',
#  'Photography',
#  'Empowerment',
#  'Video editing',
#  'Inorganic Chemistry',
#  'Programming languages',
#  'Conceptual',
#  'HR Management',
#  'Human Resources',
#  'Mass Media',
#  'International Relations',
#  'Sculptures',
#  'Artistic design',
#  'Fashion Design',
#  'Ceramics',
#  'Craft',
#  'Mathematics',
#  'Linear Algebra',
#  'Electronics & electrical Technology',
#  'Electrical Machines',
#  'Auditing',
#  'Internal Audit',
#  'E Commerce',
#  'E Transactions',
#  'Computation',
#  'Internal Financial Control',
#  'Taxation',
#  'Custom Laws',
#  'Audit Evidence',
#  'GST',
#  'Direct Tax',
#  'Secratarial Audit',
#  'Banking',
#  'Banking Companies',
#  'Banking Technology',
#  'Audit Remark',
#  'Cost Audit',
#  'Statuary Audit',
#  'Legal Studies',
#  'Legal System',
#  'Sports Coaching',
#  'Sports Law',
#  'Economics',
#  'Economics Sociology',
#  'Revenue Concept',
#  'Human Rights',
#  'Rights and Duties',
#  'Sociology',
#  'Sociology of Religion',
#  'Sociology in India',
#  'Political Science',
#  'International Politics',
#  'Colonialism In India',
#  'Labor Law',
#  'Design and Analysis of Algorithms',
#  'Computer Application',
#  'Graphics',
#  'Computer Creation',
#  'Other Online Platforms',
#  'Drawing',
#  'Shopping Platform',
#  'Hardware',
#  'Business',
#  'Business Skills',
#  'Mobile Applications',
#  'Communication',
#  'Basics of Communiaction',
#  'Prints',
#  'Marketing',
#  'Advertising',
#  'Political Thought',
#  'Accounting',
#  'Fundamental Of Accounting',
#  'Mixed Media',
#  'Management',
#  'Team Mangememnt',
#  'Corporate Social Responsibilities',
#  'Philosophy',
#  'Applied Ethics',
#  'Performance In Organization',
#  'Organizational Behaviour',
#  'Fashion Desigining',
#  'Fashion Textile',
#  'Fashion Manufacturing',
#  'Fashion Techniques',
#  'Garment Production',
#  'Garment Technology',
#  'Promotion And Distribution Decisions',
#  'Biotechnology',
#  'Genetic Engineering',
#  'Physiology',
#  'Neurology',
#  'Indian Government',
#  'Osteology',
#  'Cardiology',
#  'Zoology',
#  'Ecology',
#  'Cloud Computing',
#  'Radiology',
#  'Molecular Biology',
#  'Gastroenterology',
#  'Logic',
#  'Watercolours',
#  'Tapestry',
#  'Robotics',
#  'Data Science',
#  'Public Philosophy',
#  'Digital Marketing',
#  'Videography',
#  'Acrylics',
#  'Sports Event',
#  'Government and Politics',
#  'Geography',
#  'Physical Geography',
#  'Education',
#  'Business Organisation',
#  'Environmental Biology',
#  'Fundamental Rights',
#  'Marketing Management',
#  'Partnership Accounting',
#  'Corporate Accounting',
#  'Accounting Theory And Practices',
#  'Income Tax Laws',
#  'Articulation',
#  'Archeology',
#  'Human Prehistory',
#  'Start Ups',
#  'Entreperneurship',
#  'Business Strategies',
#  'Venture Capitalist',
#  'Business Planning',
#  'Indian Geography',
#  'Digital India',
#  'Bio-entrepreneurship',
#  'Literature',
#  'Stories',
#  'History',
#  'Indian History',
#  'ViDEO',
#  'Business Management',
#  'Social Work',
#  'Health Education',
#  'Social Tech',
#  'Humanities',
#  'Financial Accounting',
#  'Psycholgy',
#  'Social Psychology',
#  'Physics',
#  'Instrumentation',
#  'Craft work',
#  'Social Interventions',
#  'Substance Abuse',
#  'Indian Economy',
#  'Finance',
#  'Financial Analysis',
#  'Architecture',
#  'Web designing',
#  'Database Management',
#  'Movements in Literature',
#  'Atomic Physics',
#  'Energy Physics',
#  'Quantum Mecahnics',
#  'Protection & Enforcement',
#  'Environment Studies',
#  'Pollution',
#  'Industrial Instrumentation',
#  'Nuclear & Particle Physics',
#  'Environmental Biotechnology',
#  'Alternate Dispute Resolution',
#  'International Treaties',
#  'International Agreement',
#  'Principles Of Marketing',
#  'Marketing Research Methadology',
#  'International Marketing',
#  'Child Development',
#  'Break even Point',
#  'Foreign Economy',
#  'Psychological Growth',
#  'Technology Mangement',
#  'Managerial Activity',
#  'Creative And Lateral Management',
#  'Business Enviorment',
#  'New Venture Planning',
#  'Foreign Business',
#  'NGO',
#  'Fine Arts',
#  'Legal Tradition',
#  'Nationality Law',
#  'Government Law',
#  'Company Law',
#  'Banking Law',
#  'Frontend Development',
#  'Music',
#  'Wood Crafts',
#  'Wood carving',
#  '2D Composition',
#  'Mosaic painting',
#  'Video',
#  'Fashion Illustration',
#  'Pattern Cutting',
#  'Fashion Communication',
#  'Animal Biotechnology',
#  'Pattern & Culture',
#  'Fashion Trends',
#  'Fashion Portfoilio',
#  'Sketch Video',
#  'Test',
#  'Professionalism',
#  'Art',
#  'Science;Technology',
#  'Art; Science',
#  'Logo Design',
#  'Learning',
#  'Fictions',
#  'Technology',
#  'Typography',
#  'Media And Society',
#  'Science; Technology']

# %%
print("before cleaning",posts.shape)
x.index = np.arange(0,x.shape[0])
for i in range(0,x.shape[0]):
    temp=x['title'][i].split()
    for cat in categories:
        if cat in temp:
            x['category'][i]=cat
k=0
for i in range(0,posts.shape[0]):
    for j in range(0,x.shape[0]):
        if posts['title'][i]==x['title'][j]:
            posts['category'][i]=x['category'][j]

posts.dropna(axis=0,inplace=True)
print("after cleaning",posts.shape)

posts.index=np.arange(0,posts.shape[0])
# Out:
# before cleaning (493, 4)
# D:\Want To Use\Installed\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# after cleaning (468, 4)

# %%
sns.countplot(x=' post_type',data=posts)

# %% [markdown]
# ### Working on posts file

# %%
views.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1449 entries, 0 to 1448
# Data columns (total 3 columns):
# user_id      1449 non-null object
# post_id      1449 non-null object
# timestamp    1449 non-null object
# dtypes: object(3)
# memory usage: 34.0+ KB

# %%
views.describe()
# Out:
#                          user_id                   post_id  \
# count                       1449                      1449
# unique                       118                       495
# top     5d60098a653a331687083238  5ec1fd0974f7660d73aa0fd5
# freq                         230                        18
#
#                        timestamp
# count                       1449
# unique                      1449
# top     2020-04-12T19:45:29.493Z
# freq                           1

# %%
views.isnull().sum()
# Out:
# user_id      0
# post_id      0
# timestamp    0
# dtype: int64

# %%
grp = views.groupby('user_id')
grp.count()['post_id']
# Out:
# user_id
# 5d60098a653a331687083238    230
# 5d610ae1653a331687083239    137
# 5d618359fc5fcf3bdd9a0910     23
# 5d6d2bb87fa40e1417a49315     28
# 5d7c994d5720533e15c3b1e9     95
# 5d90fc1a641ef364939fb6cc      1
# 5d9a2982979d5962253c2f81      2
# 5de50d768eab6401affbb135     19
# 5ded443342a8854bf6eaba9a      1
# 5deeef6142a8854bf6eabab9     69
# 5defd51362624b0135ea9fd2     46
# 5df11ee1ee4bb5252b4f5344      1
# 5df20f1fee4bb5252b4f5351     82
# 5df24eeaee4bb5252b4f5366      3
# 5df3f8f2ee4bb5252b4f5393     34
# 5df49b32cc709107827fb3c7     30
# 5e0d5ce12a37d20505da2a5d      2
# 5e1ef04c2a37d20505da2b8b     62
# 5e26bb482a37d20505da2c10      5
# 5e3563348d344822fed4d13a     26
# 5e35a5ed8d344822fed4d13e     21
# 5e365e758d344822fed4d144      2
# 5e37b16ceab55d319938a6f8     25
# 5e4195c3eab55d319938a82c      6
# 5e4ce251f5561b1994c8e40d      1
# 5e5855ced701ab08af792b51      1
# 5e5af599d701ab08af792b63     62
# 5e5b4511d701ab08af792b6d      5
# 5e5dfbbefbc8805f69e02c91      4
# 5e783375cfc8b713f5ac7c5b      2
#                            ...
# 5ecd5a5c7023451e662235c1      1
# 5ecdf7397023451e66223784      3
# 5ece02427023451e66223861      2
# 5ecf6e6576027d35905cbeec      5
# 5ecfa94676027d35905cbf78      1
# 5ecfaa0076027d35905cbf83      1
# 5ecfbcb376027d35905cbfe5      1
# 5ecfdaa976027d35905cc02c      3
# 5ed09e8576027d35905cc164      1
# 5ed0bfc176027d35905cc1f8      3
# 5ed0cfc676027d35905cc26a      2
# 5ed0d9bc76027d35905cc2c2      1
# 5ed0defa76027d35905cc2de      5
# 5ed0dfec76027d35905cc2ec      2
# 5ed0fc0976027d35905cc448      1
# 5ed12ae476027d35905cc4a1      1
# 5ed13bb076027d35905cc4ba      2
# 5ed142cd76027d35905cc4cd      1
# 5ed232b976027d35905cc689      4
# 5ed237ee76027d35905cc6c5      6
# 5ed2399b76027d35905cc70f      6
# 5ed24d5a76027d35905cc7d7      2
# 5ed2672576027d35905cc7f6      2
# 5ed2edf176027d35905cc961      2
# 5ed350ed76027d35905cca2c      6
# 5ed35aa376027d35905cca67      4
# 5ed3737976027d35905ccaa2      1
# 5ed3748576027d35905ccaab      4
# 5ed3cbcbbd514d602c1530a7      1
# 5ed3e898bd514d602c1530de      1
# Name: post_id, Length: 118, dtype: int64

# %%
print("The user of ID:5d60098a653a331687083238, his/her name",users[users['_id']=='5d60098a653a331687083238']['name'][0],"has the top number of posts in this site!")
# Out:
# The user of ID:5d60098a653a331687083238, his/her name Nivesh Singh Chauhan has the top number of posts in this site!

# %% [markdown]
# ### Starting now with the real work!
# * Now we have a good idea about the datasets
# * The goal is to present for a given user the recommend posts
# * Also we need to classify the posts according to their similiarities (Category)

# %%
for cat in categories:
    cat.lower()
    cat.capitalize()

categories = list(dict.fromkeys(categories))
categories.sort()
categories
# Out:
# ['2D Composition',
#  'Accounting',
#  'Accounting Theory And Practices',
#  'Acrylics',
#  'Advertising',
#  'Alternate Dispute Resolution',
#  'Animal Biotechnology',
#  'Applied Ethics',
#  'Archeology',
#  'Architecture',
#  'Art',
#  'Art; Science',
#  'Articulation',
#  'Artificial Intelligence',
#  'Artistic design',
#  'Atomic Physics',
#  'Audit Evidence',
#  'Audit Remark',
#  'Auditing',
#  'Banking',
#  'Banking Companies',
#  'Banking Law',
#  'Banking Technology',
#  'Basics of Communiaction',
#  'Bio-entrepreneurship',
#  'Biotechnology',
#  'Break even Point',
#  'Business',
#  'Business Enviorment',
#  'Business Management',
#  'Business Organisation',
#  'Business Planning',
#  'Business Skills',
#  'Business Strategies',
#  'Calligraphy',
#  'Cardiology',
#  'Ceramics',
#  'Child Development',
#  'Cloud Computing',
#  'Colonialism In India',
#  'Communication',
#  'Company Law',
#  'Competition Laws',
#  'Computation',
#  'Computer Application',
#  'Computer Creation',
#  'Computer Technology',
#  'Conceptual',
#  'Corporate Accounting',
#  'Corporate Social Responsibilities',
#  'Cost Audit',
#  'Craft',
#  'Craft work',
#  'Creative And Lateral Management',
#  'Custom Laws',
#  'Data Science',
#  'Database Management',
#  'Design and Analysis of Algorithms',
#  'Digital India',
#  'Digital Marketing',
#  'Direct Tax',
#  'Drawing',
#  'Drawings',
#  'E Commerce',
#  'E Transactions',
#  'Eco System',
#  'Ecology',
#  'Economic Policies',
#  'Economics',
#  'Economics Sociology',
#  'Education',
#  'Electrical Machines',
#  'Electronics & electrical Technology',
#  'Empowerment',
#  'Energy Physics',
#  'Entreperneurship',
#  'Environment Studies',
#  'Environmental Biology',
#  'Environmental Biotechnology',
#  'Fashion Communication',
#  'Fashion Desigining',
#  'Fashion Design',
#  'Fashion Illustration',
#  'Fashion Manufacturing',
#  'Fashion Portfoilio',
#  'Fashion Techniques',
#  'Fashion Textile',
#  'Fashion Trends',
#  'Fictions',
#  'Finance',
#  'Financial Accounting',
#  'Financial Analysis',
#  'Fine Arts',
#  'Foreign Business',
#  'Foreign Economy',
#  'Frontend Development',
#  'Fundamental Of Accounting',
#  'Fundamental Rights',
#  'GST',
#  'Garment Production',
#  'Garment Technology',
#  'Gastroenterology',
#  'Genetic Engineering',
#  'Geography',
#  'Government Law',
#  'Government and Politics',
#  'Graphic',
#  'Graphic Design',
#  'Graphics',
#  'HR Management',
#  'Hardware',
#  'Health Education',
#  'History',
#  'Human Prehistory',
#  'Human Resources',
#  'Human Rights',
#  'Humanities',
#  'Illustration',
#  'Income Tax Laws',
#  'Indian Economy',
#  'Indian Geography',
#  'Indian Government',
#  'Indian History',
#  'Industrial Instrumentation',
#  'Information Technology',
#  'Inorganic Chemistry',
#  'Instrumentation',
#  'Internal Audit',
#  'Internal Financial Control',
#  'International Agreement',
#  'International Marketing',
#  'International Politics',
#  'International Relations',
#  'International Treaties',
#  'Labor Law',
#  'Learning',
#  'Legal Studies',
#  'Legal System',
#  'Legal Tradition',
#  'Linear Algebra',
#  'Literature',
#  'Logic',
#  'Logo Design',
#  'Machine Learning',
#  'Management',
#  'Managerial Activity',
#  'Marketing',
#  'Marketing Management',
#  'Marketing Research Methadology',
#  'Mass Media',
#  'Mathematics',
#  'Media And Society',
#  'Mixed Media',
#  'Mobile Applications',
#  'Molecular Biology',
#  'Mosaic painting',
#  'Movements in Literature',
#  'Music',
#  'NGO',
#  'Nationality Law',
#  'Neurology',
#  'New Venture Planning',
#  'Nuclear & Particle Physics',
#  'Operating Systems',
#  'Organizational Behaviour',
#  'Osteology',
#  'Other Online Platforms',
#  'Painting',
#  'Partnership Accounting',
#  'Pattern & Culture',
#  'Pattern Cutting',
#  'Pen and ink',
#  'Performance In Organization',
#  'Philosophy',
#  'Photography',
#  'Physical Geography',
#  'Physics',
#  'Physiology',
#  'Plant Biotechnology',
#  'Political Science',
#  'Political Thought',
#  'Pollution',
#  'Principles Of Marketing',
#  'Prints',
#  'Professionalism',
#  'Programming languages',
#  'Promotion And Distribution Decisions',
#  'Protection & Enforcement',
#  'Psycholgy',
#  'Psychological Growth',
#  'Public Philosophy',
#  'Quantum Mecahnics',
#  'Radiology',
#  'Revenue Concept',
#  'Rights and Duties',
#  'Robotics',
#  'Science; Technology',
#  'Science;Technology',
#  'Sculptures',
#  'Secratarial Audit',
#  'Shopping Platform',
#  'Sketch Video',
#  'Social Interventions',
#  'Social Psychology',
#  'Social Tech',
#  'Social Work',
#  'Sociology',
#  'Sociology in India',
#  'Sociology of Religion',
#  'Sports Coaching',
#  'Sports Event',
#  'Sports Law',
#  'Start Ups',
#  'Statuary Audit',
#  'Stories',
#  'Substance Abuse',
#  'Tapestry',
#  'Taxation',
#  'Team Mangememnt',
#  'Technology',
#  'Technology Mangement',
#  'Test',
#  'Typography',
#  'Venture Capitalist',
#  'ViDEO',
#  'Video',
#  'Video editing',
#  'Videography',
#  'Visual Arts',
#  'Watercolours',
#  'Web designing',
#  'Wood Crafts',
#  'Wood carving',
#  'Zoology']

# %% [markdown]
# #### Recommend posts for a given user

# %% [markdown]
# The recommendation will be according to a score for a post:
# * If the title already exists, the recommendation for this post will be first!
# * The descending order of categories (4.5/10)
# * The descending order of type of posts (post_type) (2.5/10)
# * Similiarity of academic level (1.5/10)
# * Gender of user (1.5/10)
#
# *Note: The number of recommendation posts shown to the user may vary between users.*

# %%
def reco_user(id):
    """
    This function takes an id of a user and print to you the recommended posts for this user
    with matching of each post according to his information
    the function contains a simple way of coding for more understanding
    if you have any problem with it (about understanding it)
    feel free to contact me on my email a_h9@bk.ru
    """
    #Assigning essential values to a fixed variables 
    indx=users[users['_id']==id]['name'].index[0]
    name=users[users['_id']==id]['name'][indx]
    gender=users[users['_id']==id]['gender'][indx]
    academics=users[users['_id']==id]['academics'][indx]
    
    #Creating a list that contains all the ID's of posts of the user
    postsID=[]
    temp=views[views['user_id']==id]['post_id']
    temp.index=np.arange(temp.shape[0])
    for tem in temp:
        postsID.append(tem)
    
    postitles=[]
    categories=[]
    count_catgs=[]
    postype=[0,0,0,0]
    for i in range(0,len(postsID)):
        #title
        x=posts[posts['_id']==postsID[i]]
        y=str(x['title'])
        if y[0:3].isdecimal():
            y=y[7:]
        else:
            y=y[6:]
        y=y.split(';')[0]
        y=y.split('\n')[0]
        postitles.append(y)
        #category
        y=str(x['category'])
        if y[0:3].isdecimal():
            y=y[7:]
        else:
            y=y[6:]
        z=y.split('|')
        for j in range(0,len(z)-1):
            if z[j] in categories:
                count_catgs[j]+=1
            else:
                categories.append(z[j])
                count_catgs.append(1)
        #post_type='blog''artwork''skill''project'
        y=str(x[' post_type'])
        if y[0:3].isdecimal():
            y=y[7:]
        else:
            y=y[6:]
        y=y.split('\n')[0]
        if y=='blog':
            postype[0]+=1
        if y=='artwork':
            postype[1]+=1
        if y=='skill':
            postype[2]+=1
        if y=='project':
            postype[3]+=1
    #Starting with recommend posts for the user according to a score
    reco_posts=[]
    scores=[]
    # posts_WID is the same file as posts.csv but without the posts of the given user
    posts_WID=posts
    for i in range(0,len(postsID)):
        posts_WID=posts_WID.drop(posts_WID.loc[posts_WID['_id']==postsID[i]].index)

    posts_WID.index = np.arange(0,posts_WID.shape[0])
    for i in range(0,len(postitles)):
        for j in range(0,posts_WID.shape[0]):
            if postitles[i] == posts_WID['title'][j]:
                reco_posts.append(posts_WID['_id'][j])
                scores.append(10)

    for post in reco_posts:
        posts_WID=posts_WID.drop(posts_WID.loc[posts_WID['_id']==post].index)
        posts_WID.index = np.arange(0,posts_WID.shape[0])

    if len(categories)>=20:
        cetegories=categories[:20]
        count_catgs=count_catgs[:20]
    else:
        cetegories=categories[:10]
        count_catgs=count_catgs[:10]
    for i in range(0,len(categories)):
        for j in range(0,posts_WID.shape[0]):
            if categories[i]==posts_WID['category'][j]:
                reco_posts.append(posts_WID['_id'][j])
                scores.append(4.5)
                index0=views[views['post_id']==posts_WID['_id'][j]]['user_id'].index[0]
                userid=views[views['post_id']==posts_WID['_id'][j]]['user_id'][index0]
                index1=users[users['_id']==userid].index[0]
                if users[users['_id']==userid]['gender'][index1]==gender:
                    scores[len(scores)-1]+=1.5
                ptype=['blog','artwork','skill','project']
                for p in ptype:
                    if posts[' post_type'][j]==p:
                        a=ptype.index(p)
                        if postype[a]==np.max(postype):
                            scores[len(scores)-1]+=2.5
                if users[users['_id']==userid]['academics'][index1]==academics:
                    scores[len(scores)-1]+=1.5
                
    print("Dear User ",name,", we recommend to you the follwing posts with matching of each posts according to your information:")
    for i in range(0,len(reco_posts)):
        print("Post #",i+1)
        idx=posts[posts['_id']==reco_posts[i]].index[0]
        print("TITLE:",posts[posts['_id']==reco_posts[i]]['title'][idx])
        print("CATEGORY:", posts[posts['_id']==reco_posts[i]]['category'][idx])
        print("POST TYPE:", posts[posts['_id']==reco_posts[i]][' post_type'][idx])
        print(scores[i]*10,"% match\n")
        

reco_user('5d60098a653a331687083238')
# Out:
# Dear User  Nivesh Singh Chauhan , we recommend to you the follwing posts with matching of each posts according to your information:
# Post # 1
# TITLE: PENCIL RENDERING
# CATEGORY: Drawings
# POST TYPE: artwork
# 100 % match
#
# Post # 2
# TITLE: PENCIL RENDERING
# CATEGORY: Drawings
# POST TYPE: artwork
# 100 % match
#
# Post # 3
# TITLE: MOSAIC ART
# CATEGORY: Visual Arts|Craft|Mixed Media|Conceptual|Mosaic painting
# POST TYPE: artwork
# 100 % match
#
# Post # 4
# TITLE: Aesthetic.
# CATEGORY: Photography
# POST TYPE: artwork
# 100 % match
#
# Post # 5
# TITLE: Aesthetics
# CATEGORY: Photography|Visual Arts
# POST TYPE: artwork
# 100 % match
#
# Post # 6
# TITLE: Concept of Revenue
# CATEGORY: Economics|Revenue Concept
# POST TYPE: blog
# 100 % match
#
# Post # 7
# TITLE: Must-Visit Hill Stations in Maharashtra
# CATEGORY: Geography|Indian Geography
# POST TYPE: blog
# 100 % match
#
# Post # 8
# TITLE: TIE AND DYE
# CATEGORY: Fashion Design
# POST TYPE: artwork
# 75.0 % match
#
# Post # 9
# TITLE: Lord Shiva
# CATEGORY: Drawings
# POST TYPE: artwork
# 75.0 % match
#
# Post # 10
# TITLE: Trident
# CATEGORY: Drawings
# POST TYPE: artwork
# 60.0 % match
#
# Post # 11
# TITLE: Lord shiva
# CATEGORY: Drawings
# POST TYPE: artwork
# 100.0 % match
#
# Post # 12
# TITLE: Kid Bu
# CATEGORY: Drawings
# POST TYPE: artwork
# 100.0 % match
#
# Post # 13
# TITLE: Shadow Sketch
# CATEGORY: Drawings
# POST TYPE: artwork
# 100.0 % match
#
# Post # 14
# TITLE: The Chosen
# CATEGORY: Drawings
# POST TYPE: artwork
# 85.0 % match
#
# Post # 15
# TITLE: Spartan
# CATEGORY: Drawings
# POST TYPE: artwork
# 60.0 % match
#
# Post # 16
# TITLE: ROMAN REIGNS
# CATEGORY: Drawings
# POST TYPE: artwork
# 100.0 % match
#
# Post # 17
# TITLE: OM
# CATEGORY: Drawings
# POST TYPE: artwork
# 85.0 % match
#
# Post # 18
# TITLE: MK Swords
# CATEGORY: Drawings
# POST TYPE: artwork
# 100.0 % match
#
# Post # 19
# TITLE: Mahakaal
# CATEGORY: Drawings
# POST TYPE: artwork
# 85.0 % match
#
# Post # 20
# TITLE: Morning nectar
# CATEGORY: Drawings
# POST TYPE: artwork
# 75.0 % match
#
# Post # 21
# TITLE: I am just hoping we'll have cake by the ocean
# CATEGORY: Drawings
# POST TYPE: artwork
# 75.0 % match
#
# Post # 22
# TITLE: Sketch
# CATEGORY: Drawings
# POST TYPE: artwork
# 60.0 % match
#
# Post # 23
# TITLE: The legend
# CATEGORY: Drawings
# POST TYPE: artwork
# 75.0 % match
#
# Post # 24
# TITLE: The sorting hat
# CATEGORY: Drawings
# POST TYPE: artwork
# 60.0 % match
#
# Post # 25
# TITLE: You are late.
# CATEGORY: Drawings
# POST TYPE: artwork
# 60.0 % match
#
# Post # 26
# TITLE: Women: goddess
# CATEGORY: Drawings
# POST TYPE: artwork
# 60.0 % match
#
# Post # 27
# TITLE: 21 day Lock down. Quarantine
# CATEGORY: Conceptual
# POST TYPE: artwork
# 75.0 % match
#
# Post # 28
# TITLE: SERP Meta Checker | Check Your Meta Preview in SERP | Tools For Search Engine Optimization
# CATEGORY: Mixed Media
# POST TYPE: artwork
# 45.0 % match
#
# Post # 29
# TITLE: Spirituality
# CATEGORY: Photography
# POST TYPE: artwork
# 85.0 % match
#
# Post # 30
# TITLE: Travelling
# CATEGORY: Photography
# POST TYPE: artwork
# 60.0 % match
#
# Post # 31
# TITLE: Leap of faith
# CATEGORY: Photography
# POST TYPE: artwork
# 85.0 % match
#
# Post # 32
# TITLE: Sunset
# CATEGORY: Photography
# POST TYPE: artwork
# 100.0 % match
#
# Post # 33
# TITLE: Peaceful
# CATEGORY: Photography
# POST TYPE: artwork
# 45.0 % match
#
# Post # 34
# TITLE: PEACE
# CATEGORY: Photography
# POST TYPE: artwork
# 60.0 % match
#
# Post # 35
# TITLE: EYES
# CATEGORY: Photography
# POST TYPE: artwork
# 60.0 % match
#
# Post # 36
# TITLE: silence
# CATEGORY: Photography
# POST TYPE: artwork
# 100.0 % match
#
# Post # 37
# TITLE: early mornings with Gang
# CATEGORY: Photography
# POST TYPE: artwork
# 60.0 % match
#
# Post # 38
# TITLE: Light to fight
# CATEGORY: Photography
# POST TYPE: artwork
# 75.0 % match
#
# Post # 39
# TITLE: Bloom to life
# CATEGORY: Photography
# POST TYPE: artwork
# 60.0 % match
#
# Post # 40
# TITLE: Colours of history
# CATEGORY: Photography
# POST TYPE: artwork
# 75.0 % match
#
# Post # 41
# TITLE: Rise and shine
# CATEGORY: Photography
# POST TYPE: artwork
# 60.0 % match
#
# Post # 42
# TITLE: Memory
# CATEGORY: Photography
# POST TYPE: artwork
# 85.0 % match
#
# Post # 43
# TITLE: CAPTURED.
# CATEGORY: Photography
# POST TYPE: artwork
# 85.0 % match
#
# Post # 44
# TITLE: Too much?
# CATEGORY: Photography
# POST TYPE: artwork
# 85.0 % match
#
# Post # 45
# TITLE: Blues
# CATEGORY: Photography
# POST TYPE: artwork
# 70.0 % match
#
# Post # 46
# TITLE: Dusk sky.
# CATEGORY: Photography
# POST TYPE: artwork
# 85.0 % match
#
# Post # 47
# TITLE: Miles to go before I sleep!
# CATEGORY: Photography
# POST TYPE: artwork
# 100.0 % match
#
# Post # 48
# TITLE: Peace.
# CATEGORY: Photography
# POST TYPE: artwork
# 85.0 % match
#
# Post # 49
# TITLE: Pleasant
# CATEGORY: Photography
# POST TYPE: artwork
# 85.0 % match
#
# Post # 50
# TITLE: Photography Composition
# CATEGORY: Photography
# POST TYPE: project
# 100.0 % match
#
# Post # 51
# TITLE: Street Art Photo by Mathilde Decourcelle
# CATEGORY: Photography
# POST TYPE: artwork
# 75.0 % match
#
# Post # 52
# TITLE: She got a new hairstyle! Photo by Chirag
# CATEGORY: Photography
# POST TYPE: artwork
# 75.0 % match
#
# Post # 53
# TITLE: Street Art by Chirag.
# CATEGORY: Photography
# POST TYPE: artwork
# 60.0 % match
#
# Post # 54
# TITLE: WisdomLeaf
# CATEGORY: Photography
# POST TYPE: artwork
# 100.0 % match
#
# Post # 55
# TITLE: Wildlife Creation.
# CATEGORY: Photography
# POST TYPE: artwork
# 75.0 % match
#
# Post # 56
# TITLE: Swift Alone!
# CATEGORY: Photography
# POST TYPE: artwork
# 70.0 % match
#
# Post # 57
# TITLE: Nature
# CATEGORY: Photography
# POST TYPE: artwork
# 100.0 % match
#
# Post # 58
# TITLE: Pebbles or Rocks 🙄
# CATEGORY: Photography
# POST TYPE: artwork
# 60.0 % match
#
# Post # 59
# TITLE: Sea Shore
# CATEGORY: Photography
# POST TYPE: artwork
# 60.0 % match
#
# Post # 60
# TITLE: Camel Shades
# CATEGORY: Photography
# POST TYPE: artwork
# 60.0 % match
#
# Post # 61
# TITLE: Blur but beautiful <3
# CATEGORY: Photography
# POST TYPE: artwork
# 60.0 % match
#
# Post # 62
# TITLE: Sky never disappoints me!
# CATEGORY: Photography
# POST TYPE: artwork
# 60.0 % match
#
# Post # 63
# TITLE: Faith in yourself
# CATEGORY: Photography
# POST TYPE: artwork
# 75.0 % match
#
# Post # 64
# TITLE: Be yourself !!
# CATEGORY: Photography
# POST TYPE: artwork
# 85.0 % match
#
# Post # 65
# TITLE: Symptoms of Corona Virus
# CATEGORY: Visual Arts
# POST TYPE: artwork
# 85.0 % match
#
# Post # 66
# TITLE: 7 Steps To Prevent COVID-19
# CATEGORY: Visual Arts
# POST TYPE: artwork
# 85.0 % match
#
# Post # 67
# TITLE: Break The Chain: Stop The Spread
# CATEGORY: Visual Arts
# POST TYPE: artwork
# 85.0 % match
#
# Post # 68
# TITLE: Is there any vaccine of COVID-19?
# CATEGORY: Visual Arts
# POST TYPE: artwork
# 85.0 % match
#
# Post # 69
# TITLE: Corona's Checklist
# CATEGORY: Visual Arts
# POST TYPE: artwork
# 85.0 % match
#
# Post # 70
# TITLE: Handwashing 101
# CATEGORY: Visual Arts
# POST TYPE: artwork
# 85.0 % match
#
# Post # 71
# TITLE: Self Quarantine
# CATEGORY: Visual Arts
# POST TYPE: artwork
# 100.0 % match
#
# Post # 72
# TITLE: Disease Prevention
# CATEGORY: Graphic Design
# POST TYPE: artwork
# 85.0 % match
#
# Post # 73
# TITLE: Smart City
# CATEGORY: Painting
# POST TYPE: artwork
# 100.0 % match
#
# Post # 74
# TITLE: Quarantine days
# CATEGORY: Painting
# POST TYPE: artwork
# 60.0 % match
#
# Post # 75
# TITLE: Sunsets in Ottawa
# CATEGORY: Painting
# POST TYPE: artwork
# 75.0 % match
#
# Post # 76
# TITLE: Mythical
# CATEGORY: Painting
# POST TYPE: artwork
# 60.0 % match
#
# Post # 77
# TITLE: Nerves
# CATEGORY: Painting
# POST TYPE: artwork
# 85.0 % match
#
# Post # 78
# TITLE: We can overcome these days!
# CATEGORY: Painting
# POST TYPE: artwork
# 60.0 % match
#
# Post # 79
# TITLE: A solar-powered microbrewery has design-led energy in Sweden
# CATEGORY: Artistic design
# POST TYPE: artwork
# 85.0 % match

# %% [markdown]
# #### Recommend posts for a given post
#
# The recommendation will be according to a score for a post:
# * If the title is same, the recommendation for this post will be first!
# * The descending order of categories (5/10)
# * The descending order of type of posts (post_type) (3/10)
# * If we have more than one category and two or more categories are commun (2/10)
#
# *Note: The number of recommendation posts shown may vary between posts.*

# %%
def reco_post(id):
    """
    This function takes an id of a post as parameter and try to find the similiar posts
    the critirea of finding similiarity is by find commun informations like post type and categories
    Also the similiarity may be because the user everytime posts about the same idea.
    The function will returns a couple of posts with a percentage of matching.
    For any question you can text me.
    """
    index=posts[posts['_id']==id]['title'].index[0]
    title=posts[posts['_id']==id]['title'][index]
    category=posts[posts['_id']==id]['category'][index]
    post_type=posts[posts['_id']==id][' post_type'][index]
    mycatgs=category.split('|')
    l=len(mycatgs)
    reco_posts=[]
    scores=[]
    itt=0
    for i in range(0,posts.shape[0]):
        itt=0
        it=0
        if id!=posts['_id'][i]:
            if posts['title'][i]==title:
                reco_posts.append(posts['_id'][i])
                scores.append(10)
                itt+=1
            if itt==0:
                cat=posts['category'][i].split('|')
                x=0
                for c in cat:
                    if c in mycatgs:
                        x+=1
                if x >= l*0.25:
                    reco_posts.append(posts['_id'][i])
                    scores.append((x+2)*5/l)
                    it+=1
                if it==0:
                    if posts[' post_type'][i]==post_type:
                        reco_posts.append(posts['_id'][i])
                        scores.append(3)
                if it!=0:
                    if posts[' post_type'][i]==post_type:
                        scores[len(reco_posts)-1]+=3
    for s in scores:
        if s<4:
            scores[scores.index(s)]+=1
            
    print("We recommend to you these posts that are similiar to the given post\n")
    for rec in reco_posts:
        index=posts[posts['_id']==rec].index[0]
        print("TITLE:", posts[posts['_id']==rec]['title'][index])
        print("ID:", rec)
        print(scores[reco_posts.index(rec)]*10,"% match \n")
    

reco_post('5d6d39567fa40e1417a4931c')
# Out:
# We recommend to you these posts that are similiar to the given post
#
# TITLE: hello there
# ID: 5d62abaa65218653a132c956
# 40 % match
#
# TITLE: What is an Operating System ?
# ID: 5d7d23315720533e15c3b1ee
# 40 % match
#
# TITLE: How Competition law evolved?
# ID: 5d80dfbc6c53455f896e600e
# 40 % match
#
# TITLE: Raghavan Committee - 2002.
# ID: 5d80e7c16c53455f896e6014
# 40 % match
#
# TITLE: Let's discuss some Case laws!
# ID: 5d80ecfd6c53455f896e601a
# 40 % match
#
# TITLE: Forms of Cartel.
# ID: 5d81323a6c53455f896e6044
# 40 % match
#
# TITLE: Biodiversity
# ID: 5d9b3514979d5962253c2f90
# 40 % match
#
# TITLE: Economic policy
# ID: 5d9b950768671220a1b2b153
# 40 % match
#
# TITLE: MIS
# ID: 5dadf6ae610ba040fbfdf5c8
# 80.0 % match
#
# TITLE: CLASSIFYING FORMS OF CARTELS
# ID: 5db2b91a99cbb90e4339c749
# 40 % match
#
# TITLE: Marital Rape - Rape is Rape
# ID: 5dd1751db802e41ed198b680
# 40 % match
#
# TITLE: The Periodic Table
# ID: 5dea816a42a8854bf6eaba89
# 40 % match
#
# TITLE: Python 3 Programming Introduction
# ID: 5e04fb252a37d20505da2a2b
# 40 % match
#
# TITLE: Workforce Diversity as a Challenge
# ID: 5e27002d2a37d20505da2c13
# 40 % match
#
# TITLE: Human Resource Management
# ID: 5e2867f6025ae20886de205a
# 40 % match
#
# TITLE: Personal growth
# ID: 5e294fd1c85ab714a7da6643
# 40 % match
#
# TITLE: Abacus
# ID: 5e2f1811c85ab714a7da670d
# 40 % match
#
# TITLE: Will AI replace humans intellectual work?
# ID: 5e31a591c85ab714a7da6760
# 40 % match
#
# TITLE: HOW INTERNAL AUDIT WORKS
# ID: 5e36db70eab55d319938a6cc
# 40 % match
#
# TITLE: E-Commerce
# ID: 5e36e7baeab55d319938a6d1
# 40 % match
#
# TITLE: SEO (Search Engine Optimization)
# ID: 5e372ee2eab55d319938a6ed
# 40 % match
#
# TITLE: IMPORTANCE OF INTERNAL FINANCIAL CONTROL
# ID: 5e37c087eab55d319938a700
# 40 % match
#
# TITLE: Custom laws
# ID: 5e37c301eab55d319938a701
# 40 % match
#
# TITLE: WHY AUDIT EVIDENCE IS NECESSARY?
# ID: 5e37c78aeab55d319938a703
# 40 % match
#
# TITLE: GOODS & SERVICE TAX (GST)
# ID: 5e37ce10eab55d319938a710
# 40 % match
#
# TITLE: DIRECT TAX
# ID: 5e37d08ceab55d319938a711
# 40 % match
#
# TITLE: SECRETARIAL AUDIT
# ID: 5e37d1afeab55d319938a712
# 40 % match
#
# TITLE: ROLE OF BANKING COMPANIES IN INDIA
# ID: 5e37d490eab55d319938a713
# 40 % match
#
# TITLE: WHAT NEW TECHNOLOGY DOES BANKS ARE USING TODAY?
# ID: 5e37d699eab55d319938a71a
# 40 % match
#
# TITLE: AUDIT REMARK
# ID: 5e37d8c9eab55d319938a71e
# 40 % match
#
# TITLE: WHY COST AUDIT IS IMPORTANT FOR A COMPANY
# ID: 5e37d9eaeab55d319938a71f
# 40 % match
#
# TITLE: WHAT IS STATUTORY AUDIT
# ID: 5e37dc1aeab55d319938a720
# 40 % match
#
# TITLE: PHP
# ID: 5e3c7293eab55d319938a74d
# 40 % match
#
# TITLE: C#(.NET)
# ID: 5e3e9cc0eab55d319938a79b
# 40 % match
#
# TITLE: BASIC STRUCTURE DOCTRINE
# ID: 5e3fc856eab55d319938a7f2
# 40 % match
#
# TITLE: SPORTS LEGISLATIONS IN INDIA
# ID: 5e3fc931eab55d319938a7f4
# 40 % match
#
# TITLE: Economics Sociology
# ID: 5e3fcb74eab55d319938a806
# 40 % match
#
# TITLE: Concept of Revenue
# ID: 5e3fcc56eab55d319938a808
# 40 % match
#
# TITLE: Human Rights and Duties
# ID: 5e3fcd38eab55d319938a81a
# 40 % match
#
# TITLE: Concept of Human Rights and Duties
# ID: 5e3fce21eab55d319938a81c
# 40 % match
#
# TITLE: Sociology of Religion
# ID: 5e3fcfcdeab55d319938a81e
# 40 % match
#
# TITLE: Sociology in India
# ID: 5e3fd10aeab55d319938a820
# 40 % match
#
# TITLE: International Politics
# ID: 5e3fd290eab55d319938a822
# 40 % match
#
# TITLE: Colonialism in India
# ID: 5e3fd3bdeab55d319938a824
# 40 % match
#
# TITLE: Labour law
# ID: 5e3fd57aeab55d319938a826
# 40 % match
#
# TITLE: PHP Variables
# ID: 5e41b98eeab55d319938a82d
# 40 % match
#
# TITLE: Operators In PHP
# ID: 5e41bd7deab55d319938a839
# 80.0 % match
#
# TITLE: Computer Graphics
# ID: 5e431bf9eab55d319938a86a
# 40 % match
#
# TITLE: Graphical Input Devices
# ID: 5e45ae70f5561b1994c8e320
# 40 % match
#
# TITLE: EDI (Electronic data interchange)
# ID: 5e45b5c9f5561b1994c8e32d
# 40 % match
#
# TITLE: E-Commerce - Business Models
# ID: 5e4c28c5f5561b1994c8e3b0
# 40 % match
#
# TITLE: E-Cash
# ID: 5e4c2e65f5561b1994c8e3bd
# 40 % match
#
# TITLE: Stereoscopic and virtual-reality systems
# ID: 5e4c3c09f5561b1994c8e3e6
# 80.0 % match
#
# TITLE: Raster graphics systems
# ID: 5e4c3d1df5561b1994c8e3f3
# 40 % match
#
# TITLE: Printers
# ID: 5e4c435cf5561b1994c8e400
# 40 % match
#
# TITLE: Business skills
# ID: 5e4d359cf5561b1994c8e424
# 40 % match
#
# TITLE: Firewall
# ID: 5e50141ed15de17a8cf1b912
# 80.0 % match
#
# TITLE: DATA AND MESSAGE SECURITY
# ID: 5e501d55d15de17a8cf1b91f
# 40 % match
#
# TITLE: Mobile Computing Technology
# ID: 5e50207cd15de17a8cf1b92c
# 40 % match
#
# TITLE: Applications of mobile computing
# ID: 5e5023f1d15de17a8cf1b939
# 40 % match
#
# TITLE: Data Transmission Modes
# ID: 5e502673d15de17a8cf1b946
# 40 % match
#
# TITLE: Topology & it's types
# ID: 5e518c9fd701ab08af79299a
# 80.0 % match
#
# TITLE: Baseband & Broadband
# ID: 5e5196b5d701ab08af7929a8
# 80.0 % match
#
# TITLE: Information System
# ID: 5e519e8fd701ab08af7929b5
# 80.0 % match
#
# TITLE: Database management system(DBMS)
# ID: 5e51a2cfd701ab08af7929c2
# 80.0 % match
#
# TITLE: Ethernet
# ID: 5e51a46ad701ab08af7929cf
# 80.0 % match
#
# TITLE: Network Model
# ID: 5e52e1b0d701ab08af7929eb
# 80.0 % match
#
# TITLE: Decision Making with 7 steps !!!
# ID: 5e52e7abd701ab08af7929f8
# 80.0 % match
#
# TITLE: Network & it's types
# ID: 5e52f2b8d701ab08af792a05
# 80.0 % match
#
# TITLE: Communication
# ID: 5e52f911d701ab08af792a12
# 40 % match
#
# TITLE: Network Security Threats
# ID: 5e52fd0ed701ab08af792a1f
# 40 % match
#
# TITLE: Concept of Revenue
# ID: 5e5b6320d701ab08af792b9d
# 40 % match
#
# TITLE: Artificial Intelligence
# ID: 5e5bdf4fd701ab08af792bfd
# 80.0 % match
#
# TITLE: Importance of Digital Marketing for Startups
# ID: 5e5e3b35fbc8805f69e02c9e
# 40 % match
#
# TITLE: What is Effective Leadership In Politics
# ID: 5e5e7e0afbc8805f69e02ca8
# 40 % match
#
# TITLE: Preparation and Presentation of Company Final Accounts
# ID: 5e5e81e8fbc8805f69e02cab
# 40 % match
#
# TITLE: Terrible Leadership And Its Influence In Companies
# ID: 5e5fcd9a49d7f322c033e02f
# 40 % match
#
# TITLE: What is Information technology?
# ID: 5e65346c85ae350860168b53
# 80.0 % match
#
# TITLE: Why Do Millennials Change Jobs?
# ID: 5e6eff8aed32a005135d6bb8
# 40 % match
#
# TITLE: Distracted? Unfocused? Used This Method To Avoid Distraction.
# ID: 5e7082f91b24db0468e90cc5
# 40 % match
#
# TITLE: 5 Best Productivity Web Apps For Students.
# ID: 5e7220891b24db0468e90ce2
# 40 % match
#
# TITLE: Textile And Apparel Testing
# ID: 5e7304761b24db0468e90ce7
# 40 % match
#
# TITLE: Benefits of Guest Posting to both Writers and Brand
# ID: 5e733f1c1b24db0468e90cf1
# 40 % match
#
# TITLE: Gynecology
# ID: 5e767d501b24db0468e90d54
# 40 % match
#
# TITLE: App Development
# ID: 5e7680361b24db0468e90d66
# 40 % match
#
# TITLE: Study of Nerves
# ID: 5e773c0bcfc8b713f5ac7ab7
# 40 % match
#
# TITLE: Corona: What it is; how to prevent it and its effect on us
# ID: 5e773c89cfc8b713f5ac7ac9
# 40 % match
#
# TITLE: Skeletal System
# ID: 5e773e15cfc8b713f5ac7ad9
# 40 % match
#
# TITLE: Protect the Heart
# ID: 5e7743ebcfc8b713f5ac7aeb
# 40 % match
#
# TITLE: What is Ecology?
# ID: 5e776c1fcfc8b713f5ac7b23
# 40 % match
#
# TITLE: Cloud Computing
# ID: 5e77738bcfc8b713f5ac7b36
# 40 % match
#
# TITLE: What is Radiology?
# ID: 5e778ffccfc8b713f5ac7b50
# 40 % match
#
# TITLE: Operating System 1
# ID: 5e77bdc2cfc8b713f5ac7be4
# 40 % match
#
# TITLE: Molecular Biology
# ID: 5e77c625cfc8b713f5ac7c0b
# 40 % match
#
# TITLE: 🍉 Watermelon lemon cooler
# ID: 5e782cd9cfc8b713f5ac7c4f
# 40 % match
#
# TITLE: Sad songs
# ID: 5e7838bdcfc8b713f5ac7c99
# 40 % match
#
# TITLE: How Does A Person's Personal Development Affect His Business Leadership Ability?
# ID: 5e7a7066cfc8b713f5ac7d88
# 40 % match
#
# TITLE: What sports will look like in the future
# ID: 5e7bd922cfc8b713f5ac7da9
# 96.66666666666669 % match
#
# TITLE: Types Of AI.
# ID: 5e7c78fdcfc8b713f5ac7daa
# 80.0 % match
#
# TITLE: Accounting As A Financial Institution.
# ID: 5e7c7a44cfc8b713f5ac7dac
# 40 % match
#
# TITLE: REAL TALK
# ID: 5e7cc074cfc8b713f5ac7db0
# 40 % match
#
# TITLE: Netflix: As a Case Study
# ID: 5e7e66e7a3258347b42f213c
# 40 % match
#
# TITLE: 100 Free University Courses Online [2020]
# ID: 5e7f4fb3a3258347b42f2156
# 40 % match
#
# TITLE: Will IPL happen this year
# ID: 5e80b40ea3258347b42f21a5
# 40 % match
#
# TITLE: Is China lying about Corona
# ID: 5e80b4cca3258347b42f21a7
# 40 % match
#
# TITLE: Is The Ozone Layer Healing Itself Because Of The World Lockdown.
# ID: 5e8164f9a3258347b42f21bf
# 40 % match
#
# TITLE: Employee Stock Option and Buyback Securities.
# ID: 5e816629a3258347b42f21c2
# 40 % match
#
# TITLE: 20 Best Data Science Certification & Courses for 2020
# ID: 5e81a441a3258347b42f21d1
# 40 % match
# TITLE: 7 Best Python Data Science Courses & Certification [2020]
# ID: 5e81a4f2a3258347b42f21d3
# 80.0 % match
#
# TITLE: 7 Steps To Stay Safe From Corona Virus
# ID: 5e81b47fa3258347b42f21d7
# 40 % match
#
# TITLE: Managing Stress Amidst Corona
# ID: 5e81ba06a3258347b42f21ef
# 40 % match
#
# TITLE: How to Maintain Physical Distance: Physical Distance 101
# ID: 5e81bc41a3258347b42f220a
# 40 % match
#
# TITLE: Work From Home: Working Under Corona's Effect
# ID: 5e81be54a3258347b42f221d
# 40 % match
#
# TITLE: Oliveres mediterrànies
# ID: 5e823908a3258347b42f2368
# 40 % match
#
# TITLE: Oliveres mediterrànies
# ID: 5e82390ea3258347b42f2369
# 40 % match
#
# TITLE: Ways to Choose the Perfect Tour or Travel Agency/Company in Bhubaneswar
# ID: 5e830dc8a3258347b42f23fb
# 40 % match
#
# TITLE: What Can I Do to Keep Myself Safe From Coronavirus ?
# ID: 5e8381cfa3258347b42f2428
# 40 % match
#
# TITLE: JUSTICE FOR NORTH EAST
# ID: 5e8448aba3258347b42f2447
# 40 % match
#
# TITLE: 8 Free Data Science Courses & Tutorials [2020]
# ID: 5e847970a3258347b42f245e
# 40 % match
#
# TITLE: Must-Visit Hill Stations in Maharashtra
# ID: 5e84a6a3a3258347b42f246e
# 40 % match
#
# TITLE: How Artificial Intelligence tools Help You To Get Smart In Your Content Marketing
# ID: 5e85054fa3258347b42f24a0
# 40 % match
#
# TITLE: What Is Amalgamation; Absorption and Reconstruction Of Companies?
# ID: 5e866cffa3258347b42f24ef
# 40 % match
#
# TITLE: Top 10 things for someone with itchy feet to do during self-isolation
# ID: 5e88a3c0a3258347b42f2572
# 40 % match
#
# TITLE: What are Set Off and Carry Forward Losses
# ID: 5e895ceca3258347b42f25b6
# 40 % match
#
# TITLE: Benefits Of A Virtual Portfolio.
# ID: 5e895d87a3258347b42f25bb
# 40 % match
#
# TITLE: 10 Best Artificial Intelligence (AI) Courses Online for 2020
# ID: 5e897ab4a3258347b42f25ca
# 80.0 % match
#
# TITLE: 5 Best Computer Networking Courses & Certification [2020]
# ID: 5e897f6ca3258347b42f25cd
# 40 % match
#
# TITLE: Are We Alone In The Universe?
# ID: 5e8bfa8aa3258347b42f2611
# 40 % match
#
# TITLE: How To Lead Your Startups After Facing Loses: Case Study
# ID: 5e8e13dca3258347b42f26f2
# 40 % match
#
# TITLE: Must-Visit Hill Stations in Maharashtra
# ID: 5e901b98a3258347b42f2708
# 40 % match
#
# TITLE: Advantages of Online Shopping Over Offline Shopping
# ID: 5e901e9da3258347b42f2711
# 40 % match
#
# TITLE: Advantages of Online Shopping Over Offline Shopping
# ID: 5e901f23a3258347b42f2725
# 40 % match
#
# TITLE: Benefits of Buying Grocery Online in Twin city of Odisha
# ID: 5e90208ca3258347b42f2730
# 40 % match
#
# TITLE: How to Choose the Right Home Cleaning Service Provider
# ID: 5e9028cea3258347b42f2736
# 40 % match
#
# TITLE: Creativity During Quarantine?
# ID: 5e908602a3258347b42f275b
# 40 % match
#
# TITLE: आमची मुंबाई !!!
# ID: 5e91a2dda3258347b42f276d
# 40 % match
#
# TITLE: SpaceX: As A Case Study
# ID: 5e9415d2a3258347b42f27f8
# 40 % match
#
# TITLE: IMPORTANCE OF MENTAL HEALTH
# ID: 5e947c4aa3258347b42f283e
# 40 % match
#
# TITLE: CYBER WORLD WAR
# ID: 5e947dcda3258347b42f2843
# 40 % match
#
# TITLE: HOW TO PREPARE YOURSELF FOR A BETTER TOMORROW?
# ID: 5e948155a3258347b42f2850
# 40 % match
#
# TITLE: Be thankful for every second of your life.
# ID: 5e94ae2fa3258347b42f28ee
# 40 % match
#
# TITLE: How Chartered Accountants See Entrepreneurship Trends
# ID: 5e94caeda3258347b42f2932
# 40 % match
#
# TITLE: The brother sister bond -  A personal touch♥️
# ID: 5e956e42a3258347b42f297f
# 40 % match
#
# TITLE: Smile more often.
# ID: 5e95a06da3258347b42f29b4
# 40 % match
#
# TITLE: Indian Space Research Organisation; ISRO.
# ID: 5e95e469a3258347b42f2a02
# 40 % match
#
# TITLE: HOW TO THINK DIFFERENTLY?
# ID: 5e95f087a3258347b42f2a16
# 40 % match
#
# TITLE: INDIA 5 TRILLION ECONOMY
# ID: 5e95f13ba3258347b42f2a1b
# 40 % match
#
# TITLE: INDIA:- SAVIOR FROM CORONA
# ID: 5e95f1a8a3258347b42f2a20
# 40 % match
#
# TITLE: REBEL?
# ID: 5e95f3a0a3258347b42f2a2c
# 40 % match
#
# TITLE: Stand alone and stand apart.
# ID: 5e95f44ba3258347b42f2a31
# 40 % match
#
# TITLE: The Best Tools For Financial Analysis.
# ID: 5e961830a3258347b42f2a4e
# 40 % match
#
# TITLE: Interesting Facts On India That You Had No Idea About
# ID: 5e964006a3258347b42f2a65
# 40 % match
#
# TITLE: 8 Best Machine Learning Courses for 2020
# ID: 5e966ad3a3258347b42f2aaf
# 96.66666666666669 % match
#
# TITLE: 10 Best UI UX Design Course & Certification [2020]
# ID: 5e966b74a3258347b42f2ab1
# 80.0 % match
#
# TITLE: Sharing is caring!
# ID: 5e973a30a3258347b42f2ada
# 40 % match
#
# TITLE: Dark Matter
# ID: 5e976a64a3258347b42f2af1
# 40 % match
#
# TITLE: Theory Of Capital Structure.
# ID: 5e978c7ca3258347b42f2b09
# 40 % match
#
# TITLE: Formation Of Trade Union
# ID: 5e9806f5a3258347b42f2b61
# 40 % match
#
# TITLE: Light Pollution And How To Solve It.
# ID: 5e980938a3258347b42f2b66
# 40 % match
#
# TITLE: Inside The Black Hole Image That Made History.
# ID: 5e99c99fa3258347b42f2c05
# 40 % match
#
# TITLE: What Can I Do to Keep Myself Safe From Coronavirus ?
# ID: 5e9aaeefa3258347b42f2c3f
# 40 % match
#
# TITLE: RAJASTHAN; an absolute beauty.
# ID: 5e9b6b20a3258347b42f2c8d
# 40 % match
#
# TITLE: Nature of Industrial Disputes.
# ID: 5e9e2760a3258347b42f2df7
# 40 % match
#
# TITLE: Innovative Marketing Strategies
# ID: 5e9eececa3258347b42f2e11
# 40 % match
#
# TITLE: Importance Of Being Productive As A Teenager
# ID: 5e9ff423a3258347b42f2e72
# 40 % match
#
# TITLE: How will the economy be affected if Nations produce what they eat?
# ID: 5ea029e9a3258347b42f2e85
# 40 % match
#
# TITLE: You; are enough!
# ID: 5ea1603a10426255a7aa9a3e
# 40 % match
#
# TITLE: How To Use Social Media To Promote A Project
# ID: 5ea30f6010426255a7aa9a9c
# 40 % match
#
# TITLE: Analysis Of Successful Companies For the Past 5 years
# ID: 5ea80a7e10426255a7aa9be2
# 40 % match
#
# TITLE: Innovative Marketing Strategies
# ID: 5ea85c1f10426255a7aa9c05
# 40 % match
#
# TITLE: Urdu Poetry
# ID: 5ea8618a10426255a7aa9c0d
# 40 % match
#
# TITLE: Factious news – The impact on youth.
# ID: 5eabeec210426255a7aa9cd2
# 40 % match
#
# TITLE: Hello world
# ID: 5eac350110426255a7aa9e92
# 40 % match
#
# TITLE: Indian Polity And Governance.
# ID: 5eac578010426255a7aa9eba
# 40 % match
#
# TITLE: Entrepreneural Training: The roadless travel
# ID: 5eadc2f710426255a7aa9ee4
# 40 % match
#
# TITLE: Corporate Influence
# ID: 5eaf322910426255a7aa9efa
# 40 % match
#
# TITLE: 6 Best + Free PLC Programming Training & Course [2020 UPDATED]
# ID: 5eaf4d4210426255a7aa9f76
# 96.66666666666669 % match
#
# TITLE: The Basic Edge of Design.
# ID: 5ebc3239514aab59896bcc86
# 40 % match
#
# TITLE: 5 points to consider while choosing a pathology lab
# ID: 5ebcf6ea514aab59896bcd09
# 40 % match
#
# TITLE: The 7 Steps of Doing A Professional Design Task.
# ID: 5ebd1111514aab59896bcd1c
# 40 % match
#
# TITLE: Importance of Design.
# ID: 5ec2b27974f7660d73aa1115
# 40 % match
#
# TITLE: Machine Learning”&“Operations" (MlOps)
# ID: 5ecd5d417023451e662235c5
# 80.0 % match
#
# TITLE: GAN's INTRODUCTION
# ID: 5ecf818376027d35905cbf03
# 80.0 % match
#
# TITLE: GAN's Part(2)
# ID: 5ecf96e876027d35905cbf46
# 80.0 % match
#
# TITLE: Recommend Systems Machine Learning
# ID: 5ecfa0ca76027d35905cbf57
# 80.0 % match
#
# TITLE: I was rejected over 200 times before I landed my first job
# ID: 5ecfafcc76027d35905cbfb0
# 40 % match
#
# TITLE: Understanding Cloud Computing(AWS)
# ID: 5ed09ad076027d35905cc15f
# 40 % match
#
# TITLE: Here are 7 of my favourite books that I've read so far this year!⠀
# ID: 5ed0e20776027d35905cc2fe
# 40 % match
#
# TITLE: Integrating Machine Learning with devOps(MLops)
# ID: 5ed141aa76027d35905cc4c9
# 40 % match
#
# TITLE: AWS services and how to launch OS on AWS Cloud
# ID: 5ed1ff0276027d35905cc60d
# 40 % match
#
# TITLE: Cloud Computing
# ID: 5ed229d976027d35905cc666
# 40 % match
#
# TITLE: Success Story Of OYO Founder Ritesh Agarwal
# ID: 5ed23e4d76027d35905cc7b8
# 40 % match
#
# TITLE: Learning...
# ID: 5ed2502b76027d35905cc7db
# 80.0 % match
#
# TITLE: CI/CD using GitHub Actions
# ID: 5ed3791976027d35905ccab6
# 80.0 % match
#
# TITLE: Configure Docker with Django; PostgreSQL; Pg-admin & Elasticsearch
# ID: 5ed3820f76027d35905ccac8
# 80.0 % match
#
# TITLE: Configure CI/CD Pipeline in GitLab and deployment to server via SSH
# ID: 5ed4cbadbd514d602c1531a6
# 80.0 % match

# %% [markdown]
# ## End of project!
